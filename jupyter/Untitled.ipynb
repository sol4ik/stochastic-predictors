# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms

from torchattacks import FGSM

# %%
t = transforms.Compose([
    transforms.ToTensor()
])

dataset = FashionMNIST("../data", train=False, transform=t)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
from

# %%
atl = FGSM(eps=0.07)

for (data, target) in dataloader:
    data = a

# %%
import pickle

# %%
with open("../experiments/exp-b04/baseline-04-act.pickle", 'rb') as act_file:
    act = pickle.load(act_file)

# %%
list(act.keys())
# Out:
# ['0', '3', '6', '8', '11', '14', '16', '19', '21', '24']

# %%
act['24']
# Out:
# [(tensor(0.0635), tensor(0.4133)),
#  (tensor(0.0621), tensor(0.4287)),
#  (tensor(0.0625), tensor(0.4213)),
#  (tensor(0.0608), tensor(0.4113)),
#  (tensor(0.0643), tensor(0.4058)),
#  (tensor(0.0604), tensor(0.4163)),
#  (tensor(0.0578), tensor(0.4282)),
#  (tensor(0.0609), tensor(0.4192)),
#  (tensor(0.0651), tensor(0.4180)),
#  (tensor(0.0606), tensor(0.4221)),
#  (tensor(0.0592), tensor(0.4145)),
#  (tensor(0.0605), tensor(0.4164)),
#  (tensor(0.0615), tensor(0.4200)),
#  (tensor(0.0567), tensor(0.4395)),
#  (tensor(0.0642), tensor(0.4308)),
#  (tensor(0.0613), tensor(0.4482)),
#  (tensor(0.0611), tensor(0.4373)),
#  (tensor(0.0570), tensor(0.4463)),
#  (tensor(0.0603), tensor(0.4424)),
#  (tensor(0.0618), tensor(0.4451)),
#  (tensor(0.0603), tensor(0.4434)),
#  (tensor(0.0583), tensor(0.4496)),
#  (tensor(0.0581), tensor(0.4492)),
#  (tensor(0.0602), tensor(0.4511)),
#  (tensor(0.0627), tensor(0.4668)),
#  (tensor(0.0631), tensor(0.4603)),
#  (tensor(0.0620), tensor(0.4659)),
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
stds = [x[1].item() for x in act['24']]

# %%
plt.hist(stds, bins=50, rwidth=0.7)
plt.yticks([])
plt.show()
