# %% [markdown]
# ## Function plot

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1 / (np.ones(x.shape) + np.exp(-1 * x))

# %%
def gaussian(x, s):
    return np.exp(- x ** 2/ (2 * s ** 2) ) / (2 * np.pi * s)

# %%
def log(x, s):
    return np.exp(-x / s) / (np.ones(x.shape) + np.exp(-x / s)) ** 2 / s

# %%
x = np.arange(-10., 10., 0.2)
sig = sigmoid(x)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# ax.spines["left"].set_position(("data", 0))
# ax.spines["bottom"].set_position(("data", 0))
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
# ax.set_yticks([])

# ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
# ax.plot(-16, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)

# ax.set_ylim(-2, 2)
# plt.plot(x, 2 * sig - 1, color="lightsalmon", linewidth=2)
plt.plot(x, log(x, 2), color="lightsalmon", linewidth=2)
plt.yticks([])
plt.xticks(np.arange(-10, 10, 2), labels=[])
plt.show()

# %%
fig, ax = plt.subplots()

x = np.linspace(-1, 1., 100)

# ax.spines["left"].set_position(("data", 0))
# ax.spines["bottom"].set_position(("data", 0))
ax.spines["left"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

ax.axhline(y=0, color='k', linewidth=1)
ax.axvline(x=0, color='k', linewidth=1)
ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)

ax.plot(x[x < -0.015], -1 * np.ones(x[x < -0.015].shape), color="lightsalmon", linewidth=2.5)
ax.plot(x[x > 0.025], np.ones(x[x > 0.025].shape), color="lightsalmon", linewidth=2.5)

plt.scatter(0., -1, marker='o', facecolors='none', edgecolors='lightsalmon', linewidths=2.5)
plt.scatter(0., 1., marker='o', facecolors='none', edgecolors='lightsalmon', linewidths=2)

ax.set_ylim(-2, 2)
plt.show()

# %%
def log(x):
    return np.exp(-x / 0.3) / (np.ones(x.shape) + np.exp(-x / 0.3)) ** 2

# %%
fig, ax = plt.subplots()

x = np.linspace(-2, 2., 100)

ax.spines["left"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

ax.axhline(y=0, color='k', linewidth=1)
ax.axvline(x=0, color='k', linewidth=1)
ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)

# ax.plot(x[(-1 < x) & (x < 1)],np.ones(x[(-1 < x) & (x < 1)].shape), color="lightsalmon", linewidth=2.5)
# ax.plot(x[x <= -0.97], np.zeros(x[x <= -0.97].shape), color="lightsalmon", linewidth=2.5)
# ax.plot(x[x >= 0.97], np.zeros(x[x >= 0.97].shape), color="lightsalmon", linewidth=2.5)

# plt.scatter(1., 1, marker='o', facecolors='none', edgecolors='lightsalmon', linewidths=2.5)
# plt.scatter(-1., 1., marker='o', facecolors='none', edgecolors='lightsalmon', linewidths=2)
# plt.scatter(1., 0., marker='o', facecolors='lightsalmon', linewidths=2)
# plt.scatter(-1., 0., marker='o', facecolors='lightsalmon', linewidths=2)

ax.plot(x, log(x), color="lightsalmon", linewidth=2.5)

ax.set_ylim(-2, 2)
plt.show()

# %% [markdown]
# ## Model accuracy plot

# %% [markdown]
# additive

# %%
x = np.arange(0, 4)

plt.bar(x - .2, [0.41, 0.78, 0.77, 0.67], width=.4)
plt.bar(x + .2, [0.41, 0.69, 0.8, 0.66], width=.4)
plt.axhline(0.9, color="black", linestyle="--")
plt.xticks([0, 1, 2, 3], ["adversarial", "σ=0.025", "σ=0.05", "σ=0.1"])
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# multiplicative

# %%
x = np.arange(0, 4)

plt.bar(x - .2, [0.41, 0.78, 0.75, 0.7], width=.4)
plt.bar(x + .2, [0.41, 0.85, 0.81, 0.72], width=.4)
plt.axhline(0.9, color="black", linestyle="--")
plt.xticks([0, 1, 2, 3], ["adversarial", "σ=0.025", "σ=0.05", "σ=0.1"])
plt.ylim(0, 1)
plt.show()

# %%
plt.plot([.2465, .2455, .2447, .2369, .2262, .1662, .1305, .0253, .0044], 'o-', label="deterministic")
plt.plot([0.3618, 0.3612, 0.3599, 0.3590, 0.3543, 0.3399, 0.3181, 0.2039, 0.1879],'o-', label="logistic, std(Z)=0.05")
plt.plot([0.2999, 0.3000, 0.3001, 0.2996, 0.2999, 0.2999, 0.2997, 0.2994, 0.2969], 'o-', label="Gaussian, std(Z)=0.05")
plt.plot([0.8612, 0.8626, 0.8600, 0.8606, 0.8580, 0.8702, 0.8554, 0.8196, 0.7828], 'o-', label="determinsitic+adversarial")
plt.xticks(list(range(9)), labels=['1e-5', '5e-5', '1e-4', '5e-4', '1e-3', '5e-3', '1e-2', '5e-2', '.1'])
plt.legend(prop={'size': 9})
plt.show()

# %% [markdown]
# missing features

# %%
plt.figure(figsize=(8, 5))
plt.plot([0.8990, 0.8964, 0.8888, 0.8790, 0.8552, 0.8170, 0.7476, 0.4777], 'o-', label="deterministic")
plt.plot([0.7581, 0.7611, 0.7648, 0.7668, 0.7681, 0.7748, 0.7674, 0.7159], 'o-', label="logisitc, std(Z)=0.05")
plt.plot([0.6000, 0.5999, 0.6000, 0.6000, 0.6000, 0.5999, 0.6010, 0.6097], 'o-', label="Gaussian, std(Z)=0.05")
plt.plot([0.5394, 0.5290, 0.5268, 0.5280, 0.5160, 0.4820, 0.4086, 0.2074], 'o-', label="detrminsitic + adversarial")
plt.xticks(list(range(8)), labels=['0.1%', '0.5%', '1%', '2%', '5%', '10%', '10%', '50%'])
plt.legend(prop={'size': 9})
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot([0.8005, 0.8005, 0.8005, 0.8005, 0.8005, 0.7844, 0.7585, 0.6107, 0.4965], 'o-', label="deterministic")
plt.plot([0.3602, 0.3600, 0.3605, 0.3628, 0.3604, 0.3432, 0.3158, 0.1799, 0.1333], 'o-', label="logisitc, std(Z)=0.05")
plt.plot([0.1001, 0.0999, 0.1000, 0.0998, 0.1000, 0.0999, 0.0998, 0.0991, 0.0957], 'o-', label="Gaussian, std(Z)=0.05")
plt.plot([0.5426, 0.5464, 0.5356, 0.5378, 0.5426, 0.5220, 0.5140, 0.4340, 0.3550], 'o-', label="detrminsitic + adversarial")
plt.xticks(list(range(9)), labels=['1e-5', '5e-5', '1e-4', '5e-4', '1e-3', '5e-3', '1e-2', '5e-2', '.1'])
plt.legend(prop={'size': 8})
plt.show()
