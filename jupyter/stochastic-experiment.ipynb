# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import yaml
import pickle

# %%
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath('..')))

# %%
import torch
import torchvision

import torchvision.transforms as transforms

from torch.utils.data import DataLoader
from torchvision.datasets import FashionMNIST

from stochastic_predictors.modules.model.cnn import StochasticCNN

# %reload_ext autoreload
# %autoreload 2

# %%
os.chdir('../modules')

# %%
def plot_history(n_exp):
    with open(f'../experiments/exp-s{n_exp}/stoch-{n_exp}-history.pickle', 'rb') as history:
        history = pickle.load(history)

    plt.clf()
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    axs[0].plot(history["train_obj"], label="train")
    axs[0].plot(history["val_obj"], label="validation")
    axs[0].set_title("Likelihood")
    axs[0].set_xlabel("epoch")
    axs[0].legend()

    axs[1].plot(history["train_acc"], label="train")
    axs[1].plot(history["val_acc"], label="validation")
    axs[1].set_title("Accuracy")
    axs[1].set_xlabel("epoch")
    axs[1].legend()

    plt.show()

# %% [markdown]
# std=0.025

# %%
# !python main.py -c ../experiments/exp-s07/config-s07.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 4834.31it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticAdditiveConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticAdditiveConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticAdditiveConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticAdditiveConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticAdditiveConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): StochasticAdditiveConv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): StochasticAdditiveConv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): StochasticAdditiveConv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): StochasticAdditiveConv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): ReLU()
# ...

# %%
# !python main.py -c ../experiments/exp-s08/config-s08.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 5294.35it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticAdditiveConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticAdditiveConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticAdditiveConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticAdditiveConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticAdditiveConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): StochasticAdditiveConv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): StochasticAdditiveConv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): StochasticAdditiveConv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): StochasticAdditiveConv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): ReLU()
# ...

# %%
# !python main.py -c ../experiments/exp-s07/config-s07.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 5098.77it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticAdditiveConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticAdditiveConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticAdditiveConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticAdditiveConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticAdditiveConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): StochasticAdditiveConv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): StochasticAdditiveConv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): StochasticAdditiveConv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): StochasticAdditiveConv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): ReLU()
# ...

# %%
# !python main.py -c ../experiments/exp-s05/config-s05.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 3494.12it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticAdditiveConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticAdditiveConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticAdditiveConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticAdditiveConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticAdditiveConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): StochasticAdditiveConv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): StochasticAdditiveConv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): StochasticAdditiveConv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): StochasticAdditiveConv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): ReLU()
# ...

# %%
# !python main.py -c ../experiments/exp-s06/config-s06.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 5789.68it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticAdditiveConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticAdditiveConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticAdditiveConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticAdditiveConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticAdditiveConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): StochasticAdditiveConv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): StochasticAdditiveConv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): StochasticAdditiveConv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): StochasticAdditiveConv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): ReLU()
# ...

# %%
# !python main.py -c ../experiments/exp-s00/config-s00.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 7034.14it/s]
#
# model:
# StochasticCNN(
#   (0): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): StochasticSignSTE()
#   (2): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): StochasticSignSTE()
#   (4): Conv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): StochasticSignSTE()
#   (7): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): StochasticSignSTE()
#   (9): Conv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): StochasticSignSTE()
#   (12): Conv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): Conv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): StochasticSignSTE()
#   (15): Conv2d(50, 10, kernel_size=(1, 1), stride=(1, 1))
#   (16): StochasticSignSTE()
# ...

# %%
plot_history("00")

# %%
# !python main.py -c ../experiments/exp-s01/config-s01.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 4721.25it/s]
#
# model:
# StochasticCNN(
#   (0): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): StochasticSignSTE()
#   (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (4): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): StochasticSignSTE()
#   (6): Conv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (7): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (9): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): StochasticSignSTE()
#   (11): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
# ...

# %%
plot_history("01")

# %%
# !python main.py -c ../experiments/exp-s02/config-s02.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 6650.00it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): StochasticConv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): StochasticConv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): StochasticConv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): StochasticConv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): ReLU()
#   (15): StochasticConv2d(50, 10, kernel_size=(1, 1), stride=(1, 1))
#   (16): ReLU()
# ...

# %%
plot_history("02")

# %%
# !python main.py -c ../experiments/exp-s03/config-s03.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 6423.13it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): StochasticConv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): StochasticConv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): StochasticConv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): StochasticConv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): ReLU()
#   (15): StochasticConv2d(50, 10, kernel_size=(1, 1), stride=(1, 1))
#   (16): ReLU()
# ...

# %%
# !python main.py -c ../experiments/exp-s04/config-s04.yaml
# Out:
# reading config file...
# setting up the experiment...
# /usr/lib/python3.9/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 5048.98it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
# ...

# %%
# %%script false --no-raise-error
#
# !python main.py -c ../experiments/exp-b00/config-b00.yaml

# %%
plot_history("00")

# %% [markdown]
# Multiplicative Gaussian
# $\mu$ = 0
# $\sigma$ = .5

# %%
# !python main.py -c ../experiments/exp-s04/config-s04.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 4882.46it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticMultiplicativeConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticMultiplicativeConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticMultiplicativeConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticMultiplicativeConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticMultiplicativeConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): StochasticMultiplicativeConv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): StochasticMultiplicativeConv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): StochasticMultiplicativeConv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
# ...

# %%
# !python main.py -c ../experiments/exp-s05/config-s05.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 6195.43it/s]
#
# model:
# StochasticCNN(
#   (0): StochasticAdditiveConv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): StochasticAdditiveConv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): StochasticAdditiveConv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): StochasticAdditiveConv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): StochasticAdditiveConv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): StochasticAdditiveConv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): StochasticAdditiveConv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): StochasticAdditiveConv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): StochasticAdditiveConv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): ReLU()
# ...
