# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import yaml
import pickle

# %%
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath('..')))

# %%
import torch
import torchvision

import torchvision.transforms as transforms

from torch.utils.data import DataLoader
from torchvision.datasets import FashionMNIST

from stochastic_predictors.modules.model.cnn import StochasticCNN

# %reload_ext autoreload
# %autoreload 2

# %%
os.chdir('../modules')

# %%
def plot_history(n_exp):
    with open(f'../experiments/exp-b{n_exp}/baseline-{n_exp}-history.pickle', 'rb') as history:
        history = pickle.load(history)

    plt.clf()
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    axs[0].plot(history["train_obj"], label="train")
    axs[0].plot(history["val_obj"], label="validation")
    axs[0].set_title("Likelihood")
    axs[0].set_xlabel("epoch")
    axs[0].legend()

    axs[1].plot(history["train_acc"], label="train")
    axs[1].plot(history["val_acc"], label="validation")
    axs[1].set_title("Accuracy")
    axs[1].set_xlabel("epoch")
    axs[1].legend()

    plt.show()

# %%
# !python main.py -c ../experiments/exp-b04/config-b04.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 4816.73it/s]
#
# model:
# StochasticCNN(
#   (0): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (4): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU()
#   (6): Conv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (7): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (9): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (12): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (13): ReLU()
#   (14): Conv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (15): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (17): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): ReLU()
#   (19): Conv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (20): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (21): Conv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (22): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (23): ReLU()
#   (24): Conv2d(50, 10, kernel_size=(1, 1), stride=(1, 1))
#   (25): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): ReLU()
#   (27): Flatten(start_dim=1, end_dim=-1)
# )
#
# using device  cuda
#
# training...
#
# Epoch: 1 / 100
# 	train loss: 1.9325458449045818, val loss: 1.8340988660812378
# 	train accuracy 0.7403333333333333, val accuracy: 0.8215
# Epoch: 2 / 100
# 	train loss: 1.8127782066345215, val loss: 1.771827452468872
# 	train accuracy 0.84445, val accuracy: 0.8539
# Epoch: 3 / 100
# 	train loss: 1.7618139097213745, val loss: 1.7272812259674073
# 	train accuracy 0.8659666666666667, val accuracy: 0.8679
# Epoch: 4 / 100
# 	train loss: 1.7237226879755656, val loss: 1.7026626583099365
# 	train accuracy 0.8799333333333333, val accuracy: 0.8746
# Epoch: 5 / 100
# 	train loss: 1.694698468017578, val loss: 1.6701149120330812
# 	train accuracy 0.8869666666666667, val accuracy: 0.8806
# Epoch: 6 / 100
# 	train loss: 1.6712645200093588, val loss: 1.6584089382171632
# 	train accuracy 0.8937333333333334, val accuracy: 0.8843
# Epoch: 7 / 100
# 	train loss: 1.650582345835368, val loss: 1.6381638858795167
# 	train accuracy 0.8995833333333333, val accuracy: 0.8887
# Epoch: 8 / 100
# 	train loss: 1.6344354016621907, val loss: 1.6297523038864137
# 	train accuracy 0.90375, val accuracy: 0.888
# Epoch: 9 / 100
# 	train loss: 1.6195151582082112, val loss: 1.6211043264389038
# 	train accuracy 0.9095, val accuracy: 0.893
# Epoch: 10 / 100
# 	train loss: 1.6081667358398437, val loss: 1.6113874572753906
# 	train accuracy 0.91265, val accuracy: 0.8923
# Epoch: 11 / 100
# 	train loss: 1.5973003512064616, val loss: 1.6049350345611573
# 	train accuracy 0.9168, val accuracy: 0.8942
# Epoch: 12 / 100
# 	train loss: 1.588290710703532, val loss: 1.602958334159851
# 	train accuracy 0.9198166666666666, val accuracy: 0.8933
# Epoch: 13 / 100
# 	train loss: 1.5794825636545817, val loss: 1.5961815162658692
# 	train accuracy 0.92295, val accuracy: 0.8926
# Epoch: 14 / 100
# 	train loss: 1.5727583614349365, val loss: 1.587944253730774
# 	train accuracy 0.9260833333333334, val accuracy: 0.8985
# Epoch: 15 / 100
# 	train loss: 1.5666889218012492, val loss: 1.5881414176940918
# 	train accuracy 0.9282, val accuracy: 0.895
# Epoch: 16 / 100
# 	train loss: 1.5613298512776692, val loss: 1.583969146347046
# 	train accuracy 0.931, val accuracy: 0.8961
# Epoch: 17 / 100
# 	train loss: 1.5555929712931316, val loss: 1.5828320922851562
# 	train accuracy 0.9336166666666667, val accuracy: 0.8955
# Epoch: 18 / 100
# 	train loss: 1.5504311508178712, val loss: 1.5788200883865355
# 	train accuracy 0.9364333333333333, val accuracy: 0.8985
# Epoch: 19 / 100
# 	train loss: 1.547526562309265, val loss: 1.5779899354934692
# 	train accuracy 0.93715, val accuracy: 0.8988
# Epoch: 20 / 100
# 	train loss: 1.543620351409912, val loss: 1.57393451461792
# 	train accuracy 0.9394333333333333, val accuracy: 0.9011
# Epoch: 21 / 100
# 	train loss: 1.5400614997863769, val loss: 1.5766341812133788
# 	train accuracy 0.94095, val accuracy: 0.8968
# Epoch: 22 / 100
# 	train loss: 1.536026070658366, val loss: 1.5760231990814209
# 	train accuracy 0.9432833333333334, val accuracy: 0.8956
# Epoch: 23 / 100
# 	train loss: 1.533820594215393, val loss: 1.5716862394332887
# 	train accuracy 0.9445333333333333, val accuracy: 0.8996
# Epoch: 24 / 100
# 	train loss: 1.5307887327194214, val loss: 1.571982283782959
# 	train accuracy 0.94665, val accuracy: 0.8992
# Epoch: 25 / 100
# 	train loss: 1.5286158791859945, val loss: 1.575040030860901
# 	train accuracy 0.9477666666666666, val accuracy: 0.8967
# Epoch: 26 / 100
# 	train loss: 1.5265315209070842, val loss: 1.5738624927520752
# 	train accuracy 0.9492, val accuracy: 0.8957
# Epoch: 27 / 100
# 	train loss: 1.5245636828740439, val loss: 1.571915625
# 	train accuracy 0.9505666666666667, val accuracy: 0.8978
# Epoch: 28 / 100
# 	train loss: 1.522526047515869, val loss: 1.5680846355438232
# 	train accuracy 0.9514, val accuracy: 0.9001
# Epoch: 29 / 100
# 	train loss: 1.5213652460734048, val loss: 1.5716034759521484
# 	train accuracy 0.9519166666666666, val accuracy: 0.8969
# Epoch: 30 / 100
# 	train loss: 1.5184461164474488, val loss: 1.5665309129714966
# 	train accuracy 0.9540333333333333, val accuracy: 0.9007
# Epoch: 31 / 100
# 	train loss: 1.5174963677724203, val loss: 1.5699043199539184
# 	train accuracy 0.9546833333333333, val accuracy: 0.898
# Epoch: 32 / 100
# 	train loss: 1.5153619119644166, val loss: 1.567985902404785
# 	train accuracy 0.9563333333333334, val accuracy: 0.8995
# Epoch: 33 / 100
# 	train loss: 1.514271175956726, val loss: 1.5689613130569457
# 	train accuracy 0.9567333333333333, val accuracy: 0.8974
# Epoch: 34 / 100
# 	train loss: 1.5125237112045289, val loss: 1.5653049537658692
# 	train accuracy 0.9582, val accuracy: 0.9012
# Epoch: 35 / 100
# 	train loss: 1.5120175110499063, val loss: 1.5641353900909425
# 	train accuracy 0.9579833333333333, val accuracy: 0.9025
# Epoch: 36 / 100
# 	train loss: 1.5103910531361897, val loss: 1.5661505653381347
# 	train accuracy 0.9587, val accuracy: 0.8994
# Epoch: 37 / 100
# 	train loss: 1.5092904910405478, val loss: 1.5657361989974976
# 	train accuracy 0.9602833333333334, val accuracy: 0.9006
# Epoch: 38 / 100
# 	train loss: 1.5087000717163086, val loss: 1.5664368717193604
# 	train accuracy 0.9604666666666667, val accuracy: 0.8996
# Epoch: 39 / 100
# 	train loss: 1.5061892139434814, val loss: 1.567515389251709
# 	train accuracy 0.96265, val accuracy: 0.8981
# Epoch: 40 / 100
# 	train loss: 1.5064962590535482, val loss: 1.568942032623291
# 	train accuracy 0.9623, val accuracy: 0.8967
# Epoch: 41 / 100
# 	train loss: 1.5049917124430339, val loss: 1.563121676826477
# 	train accuracy 0.9637166666666667, val accuracy: 0.9016
# Epoch: 42 / 100
# 	train loss: 1.5050012281417846, val loss: 1.565207740020752
# 	train accuracy 0.9628833333333333, val accuracy: 0.9003
# Epoch: 43 / 100
# 	train loss: 1.5037437169392904, val loss: 1.566979656982422
# 	train accuracy 0.9638833333333333, val accuracy: 0.8977
# Epoch: 44 / 100
# 	train loss: 1.503234457651774, val loss: 1.5631688913345336
# 	train accuracy 0.96465, val accuracy: 0.9015
# Epoch: 45 / 100
# 	train loss: 1.5022072174708048, val loss: 1.5659781929016112
# 	train accuracy 0.9653666666666667, val accuracy: 0.8988
# Epoch: 46 / 100
# 	train loss: 1.5012924355189006, val loss: 1.5640516244888305
# 	train accuracy 0.96585, val accuracy: 0.9003
# Epoch: 47 / 100
# 	train loss: 1.5008646918614705, val loss: 1.5648076723098754
# 	train accuracy 0.9663333333333334, val accuracy: 0.8995
# Epoch: 48 / 100
# 	train loss: 1.5001918647766113, val loss: 1.5630026189804078
# 	train accuracy 0.9668, val accuracy: 0.9008
# Epoch: 49 / 100
# 	train loss: 1.4988637359619141, val loss: 1.5649882781982423
# 	train accuracy 0.96795, val accuracy: 0.8995
# Epoch: 50 / 100
# 	train loss: 1.4992812545776366, val loss: 1.5658802238464355
# 	train accuracy 0.9670666666666666, val accuracy: 0.8986
# Epoch: 51 / 100
# 	train loss: 1.4982896262486776, val loss: 1.5654207012176513
# 	train accuracy 0.9682166666666666, val accuracy: 0.8975
# Epoch: 52 / 100
# 	train loss: 1.497370752588908, val loss: 1.5636013261795043
# 	train accuracy 0.9689333333333333, val accuracy: 0.901
# Epoch: 53 / 100
# 	train loss: 1.4965206592559814, val loss: 1.56347234916687
# 	train accuracy 0.9696666666666667, val accuracy: 0.8998
# Epoch: 54 / 100
# 	train loss: 1.497457681910197, val loss: 1.5639646488189698
# 	train accuracy 0.9686, val accuracy: 0.9009
# Epoch: 55 / 100
# 	train loss: 1.495571685409546, val loss: 1.56167217502594
# 	train accuracy 0.9706333333333333, val accuracy: 0.9019
# Epoch: 56 / 100
# 	train loss: 1.4959492643992107, val loss: 1.5662938238143922
# 	train accuracy 0.9699, val accuracy: 0.8971
# Epoch: 57 / 100
# 	train loss: 1.4948131509145102, val loss: 1.563428476715088
# 	train accuracy 0.9706666666666667, val accuracy: 0.9003
# Epoch: 58 / 100
# 	train loss: 1.4951142551422119, val loss: 1.563622243309021
# 	train accuracy 0.9705, val accuracy: 0.8998
# Epoch: 59 / 100
# 	train loss: 1.4938195552190145, val loss: 1.5634921222686768
# 	train accuracy 0.9721, val accuracy: 0.9
# Epoch: 60 / 100
# 	train loss: 1.4935876856486003, val loss: 1.56821817779541
# 	train accuracy 0.97155, val accuracy: 0.8939
# Epoch: 61 / 100
# 	train loss: 1.4935638633728028, val loss: 1.5645905433654785
# 	train accuracy 0.9718333333333333, val accuracy: 0.8996
# Epoch: 62 / 100
# 	train loss: 1.4927685747782389, val loss: 1.564960220527649
# 	train accuracy 0.9725333333333334, val accuracy: 0.8991
# Epoch: 63 / 100
# 	train loss: 1.4929594832102457, val loss: 1.5641387357711791
# 	train accuracy 0.9722166666666666, val accuracy: 0.899
# Epoch: 64 / 100
# 	train loss: 1.4918209948221843, val loss: 1.5632174657821656
# 	train accuracy 0.9732833333333333, val accuracy: 0.9002
# Epoch: 65 / 100
# 	train loss: 1.49215714747111, val loss: 1.5639564041137695
# 	train accuracy 0.9728166666666667, val accuracy: 0.8987
# Epoch: 66 / 100
# 	train loss: 1.4903929701487224, val loss: 1.56303466091156
# 	train accuracy 0.9744833333333334, val accuracy: 0.8998
# Epoch: 67 / 100
# 	train loss: 1.4910038295745849, val loss: 1.5650419002532958
# 	train accuracy 0.9742666666666666, val accuracy: 0.8968
# Epoch: 68 / 100
# 	train loss: 1.4904415428161621, val loss: 1.5625853763580322
# 	train accuracy 0.9744666666666667, val accuracy: 0.8988
# Epoch: 69 / 100
# 	train loss: 1.4907775767008464, val loss: 1.5638399753570558
# 	train accuracy 0.9743666666666667, val accuracy: 0.9
# Epoch: 70 / 100
# 	train loss: 1.4904739960988362, val loss: 1.5661723527908324
# 	train accuracy 0.9740833333333333, val accuracy: 0.8964
# Epoch: 71 / 100
# 	train loss: 1.4902390802383423, val loss: 1.5619121810913086
# 	train accuracy 0.97425, val accuracy: 0.9005
# Epoch: 72 / 100
# 	train loss: 1.4895771746317545, val loss: 1.5626567050933837
# 	train accuracy 0.9752666666666666, val accuracy: 0.8997
# Epoch: 73 / 100
# 	train loss: 1.4893796464284261, val loss: 1.5626280708312987
# 	train accuracy 0.97505, val accuracy: 0.8998
# Epoch: 74 / 100
# 	train loss: 1.4892417322794596, val loss: 1.5637005643844604
# 	train accuracy 0.97505, val accuracy: 0.9005
# Epoch: 75 / 100
# 	train loss: 1.489067755317688, val loss: 1.5622151784896852
# 	train accuracy 0.9750666666666666, val accuracy: 0.9003
# Epoch: 76 / 100
# 	train loss: 1.4879882726669311, val loss: 1.5638235042572022
# 	train accuracy 0.9763166666666667, val accuracy: 0.8998
# Epoch: 77 / 100
# 	train loss: 1.4877464270273844, val loss: 1.564184271621704
# 	train accuracy 0.97655, val accuracy: 0.8994
# Epoch: 78 / 100
# 	train loss: 1.4871980548858643, val loss: 1.5642028453826904
# 	train accuracy 0.9770833333333333, val accuracy: 0.8996
# Epoch: 79 / 100
# 	train loss: 1.488198955154419, val loss: 1.5648555877685546
# 	train accuracy 0.9758, val accuracy: 0.898
# Epoch: 80 / 100
# 	train loss: 1.4867424038569133, val loss: 1.5643460231781006
# 	train accuracy 0.97705, val accuracy: 0.8995
# Epoch: 81 / 100
# 	train loss: 1.4875672040939332, val loss: 1.562039779472351
# 	train accuracy 0.9766666666666667, val accuracy: 0.9007
# Epoch: 82 / 100
# 	train loss: 1.4871260105133057, val loss: 1.563416312789917
# 	train accuracy 0.9769166666666667, val accuracy: 0.8985
# Epoch: 83 / 100
# 	train loss: 1.4855240702311199, val loss: 1.566743398475647
# 	train accuracy 0.9783333333333334, val accuracy: 0.8954
# Epoch: 84 / 100
# 	train loss: 1.485707484817505, val loss: 1.5626804634094238
# 	train accuracy 0.97845, val accuracy: 0.8994
# Epoch: 85 / 100
# 	train loss: 1.4864882019678751, val loss: 1.564910093307495
# 	train accuracy 0.9774, val accuracy: 0.8975
# Epoch: 86 / 100
# 	train loss: 1.4859488642374674, val loss: 1.5642715768814086
# 	train accuracy 0.9776666666666667, val accuracy: 0.897
# Epoch: 87 / 100
# 	train loss: 1.4861033662160237, val loss: 1.5639298028945923
# 	train accuracy 0.9776, val accuracy: 0.9001
# Epoch: 88 / 100
# 	train loss: 1.4848719332377116, val loss: 1.5646453268051148
# 	train accuracy 0.9789666666666667, val accuracy: 0.899
# Epoch: 89 / 100
# 	train loss: 1.484943435605367, val loss: 1.56646774559021
# 	train accuracy 0.9788833333333333, val accuracy: 0.8957
# Epoch: 90 / 100
# 	train loss: 1.4857973417917887, val loss: 1.5624654985427857
# 	train accuracy 0.9781833333333333, val accuracy: 0.8998
# Epoch: 91 / 100
# 	train loss: 1.4851673140207926, val loss: 1.564509866142273
# 	train accuracy 0.9785333333333334, val accuracy: 0.8977
# Epoch: 92 / 100
# 	train loss: 1.484551117960612, val loss: 1.5639546669006348
# 	train accuracy 0.9791, val accuracy: 0.8982
# Epoch: 93 / 100
# 	train loss: 1.4839453988393148, val loss: 1.5620185140609741
# 	train accuracy 0.9798166666666667, val accuracy: 0.9009
# Epoch: 94 / 100
# 	train loss: 1.4847582997004192, val loss: 1.5640687513351441
# 	train accuracy 0.979, val accuracy: 0.8977
# Epoch: 95 / 100
# 	train loss: 1.4838284816741942, val loss: 1.5629032138824464
# 	train accuracy 0.9796, val accuracy: 0.8998
# Epoch: 96 / 100
# 	train loss: 1.4839641338348388, val loss: 1.562639804458618
# 	train accuracy 0.9795166666666667, val accuracy: 0.8995
# Epoch: 97 / 100
# 	train loss: 1.4842807744344075, val loss: 1.561181219482422
# 	train accuracy 0.9790833333333333, val accuracy: 0.9009
# Epoch: 98 / 100
# 	train loss: 1.484117071533203, val loss: 1.5627670932769775
# 	train accuracy 0.9795666666666667, val accuracy: 0.8993
# Epoch: 99 / 100
# 	train loss: 1.483323372777303, val loss: 1.565676256942749
# 	train accuracy 0.9802666666666666, val accuracy: 0.8952
# Epoch: 100 / 100
# 	train loss: 1.4829698001225788, val loss: 1.5623406534194946
# 	train accuracy 0.98065, val accuracy: 0.9
#
# saving history...
# saving model...
#
# done!

# %%
# %%script false --no-raise-error
#
# !python main.py -c ../experiments/exp-b00/config-b00.yaml

# %%
plot_history("00")

# %%
# !python main.py -c ../experiments/exp-b01/config-b01.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 17/17 [00:00<00:00, 3735.30it/s]
#
# model:
# StochasticCNN(
#   (0): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): Sigmoid()
#   (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (4): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): Sigmoid()
#   (6): Conv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (7): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (9): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): Sigmoid()
#   (11): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (12): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (13): Sigmoid()
#   (14): Conv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (15): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (17): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): Sigmoid()
#   (19): Conv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (20): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (21): Conv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (22): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (23): Sigmoid()
#   (24): Conv2d(50, 10, kernel_size=(1, 1), stride=(1, 1))
#   (25): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): Flatten(start_dim=1, end_dim=-1)
# )
#
# using device  cuda
#
# training...
#
# Epoch: 1 / 50
# 	train loss: -0.6650968019803365, val loss: -0.7604140880584717
# 	train accuracy 0.8156, val accuracy: 0.8452
# Epoch: 2 / 50
# 	train loss: -0.7990443599065145, val loss: -0.7951526251792908
# 	train accuracy 0.8564666666666667, val accuracy: 0.8372
# Epoch: 3 / 50
# 	train loss: -0.836843231010437, val loss: -0.8293520871162414
# 	train accuracy 0.8688, val accuracy: 0.8547
# Epoch: 4 / 50
# 	train loss: -0.8566110540072123, val loss: -0.8505359577178955
# 	train accuracy 0.8773833333333333, val accuracy: 0.8644
# Epoch: 5 / 50
# 	train loss: -0.8678628202120463, val loss: -0.8661511625289917
# 	train accuracy 0.8827, val accuracy: 0.8754
# Epoch: 6 / 50
# 	train loss: -0.8773805576960246, val loss: -0.8734035180091858
# 	train accuracy 0.8889, val accuracy: 0.8829
# Epoch: 7 / 50
# 	train loss: -0.8813611265500386, val loss: -0.8364821399688721
# 	train accuracy 0.8899833333333333, val accuracy: 0.8437
# Epoch: 8 / 50
# 	train loss: -0.8849624245325725, val loss: -0.8777815453529358
# 	train accuracy 0.8926166666666666, val accuracy: 0.884
# Epoch: 9 / 50
# 	train loss: -0.8902164647420248, val loss: -0.8863094312667846
# 	train accuracy 0.89665, val accuracy: 0.89
# Epoch: 10 / 50
# 	train loss: -0.8934728646914164, val loss: -0.8826834236145019
# 	train accuracy 0.899, val accuracy: 0.8885
# Epoch: 11 / 50
# 	train loss: -0.8984157752990722, val loss: -0.8911416275024414
# 	train accuracy 0.9035, val accuracy: 0.8946
# Epoch: 12 / 50
# 	train loss: -0.8995635442097982, val loss: -0.8880581413269043
# 	train accuracy 0.9038666666666667, val accuracy: 0.8911
# Epoch: 13 / 50
# 	train loss: -0.9007852695465088, val loss: -0.8853711233139038
# 	train accuracy 0.9050166666666667, val accuracy: 0.8881
# Epoch: 14 / 50
# 	train loss: -0.9035869622866313, val loss: -0.8920058731079101
# 	train accuracy 0.9073833333333333, val accuracy: 0.8938
# Epoch: 15 / 50
# 	train loss: -0.9044315165519714, val loss: -0.8848950653076172
# 	train accuracy 0.9082666666666667, val accuracy: 0.8885
# Epoch: 16 / 50
# 	train loss: -0.9087757960001628, val loss: -0.8968213045120239
# 	train accuracy 0.9126, val accuracy: 0.8992
# Epoch: 17 / 50
# 	train loss: -0.9087759131749471, val loss: -0.8952084470748901
# 	train accuracy 0.9120166666666667, val accuracy: 0.897
# Epoch: 18 / 50
# 	train loss: -0.9114408213933309, val loss: -0.9006615431785584
# 	train accuracy 0.9145666666666666, val accuracy: 0.9019
# Epoch: 19 / 50
# 	train loss: -0.9128888249397278, val loss: -0.898565517616272
# 	train accuracy 0.9164833333333333, val accuracy: 0.9005
# Epoch: 20 / 50
# 	train loss: -0.915764590771993, val loss: -0.9014695281028747
# 	train accuracy 0.91835, val accuracy: 0.9044
# Epoch: 21 / 50
# 	train loss: -0.9169916358311971, val loss: -0.8994185113906861
# 	train accuracy 0.9198333333333333, val accuracy: 0.9018
# Epoch: 22 / 50
# 	train loss: -0.916527532641093, val loss: -0.8956373503684998
# 	train accuracy 0.9196166666666666, val accuracy: 0.8977
# Epoch: 23 / 50
# 	train loss: -0.9198170282681783, val loss: -0.9049354948043823
# 	train accuracy 0.9222666666666667, val accuracy: 0.907
# Epoch: 24 / 50
# 	train loss: -0.9209644462585449, val loss: -0.8994452672958374
# 	train accuracy 0.9238166666666666, val accuracy: 0.9018
# Epoch: 25 / 50
# 	train loss: -0.9202778483072916, val loss: -0.8881562885284424
# 	train accuracy 0.9224333333333333, val accuracy: 0.8888
# Epoch: 26 / 50
# 	train loss: -0.9228151996612549, val loss: -0.8814926820755005
# 	train accuracy 0.9254166666666667, val accuracy: 0.8837
# Epoch: 27 / 50
# 	train loss: -0.9253433574994405, val loss: -0.8991421262741088
# 	train accuracy 0.9276833333333333, val accuracy: 0.901
# Epoch: 28 / 50
# 	train loss: -0.9264256825764974, val loss: -0.9057371891975403
# 	train accuracy 0.9283833333333333, val accuracy: 0.9077
# Epoch: 29 / 50
# 	train loss: -0.927889460627238, val loss: -0.9039697237014771
# 	train accuracy 0.9303166666666667, val accuracy: 0.9052
# Epoch: 30 / 50
# 	train loss: -0.9271762960751851, val loss: -0.9034940284729004
# 	train accuracy 0.9296666666666666, val accuracy: 0.9049
# Epoch: 31 / 50
# 	train loss: -0.9293264886220296, val loss: -0.9039218438148499
# 	train accuracy 0.9317666666666666, val accuracy: 0.9057
# Epoch: 32 / 50
# 	train loss: -0.9299620510101319, val loss: -0.905148072719574
# 	train accuracy 0.9321, val accuracy: 0.9069
# Epoch: 33 / 50
# 	train loss: -0.9321194697380066, val loss: -0.8990383205413819
# 	train accuracy 0.9340666666666667, val accuracy: 0.901
# Epoch: 34 / 50
# 	train loss: -0.931712474822998, val loss: -0.9043656621932984
# 	train accuracy 0.9336666666666666, val accuracy: 0.9055
# Epoch: 35 / 50
# 	train loss: -0.9338701763470968, val loss: -0.9026954307556152
# 	train accuracy 0.9357333333333333, val accuracy: 0.9042
# Epoch: 36 / 50
# 	train loss: -0.9332439491907756, val loss: -0.9062335603713989
# 	train accuracy 0.93505, val accuracy: 0.9075
# Epoch: 37 / 50
# 	train loss: -0.93667156457901, val loss: -0.9108351854324341
# 	train accuracy 0.93875, val accuracy: 0.9131
# Epoch: 38 / 50
# 	train loss: -0.9357195072174073, val loss: -0.9075179084777832
# 	train accuracy 0.9375833333333333, val accuracy: 0.9086
# Epoch: 39 / 50
# 	train loss: -0.9372558938980102, val loss: -0.907791143989563
# 	train accuracy 0.9391, val accuracy: 0.9097
# Epoch: 40 / 50
# 	train loss: -0.9389207928021749, val loss: -0.9018565420150757
# 	train accuracy 0.9406166666666667, val accuracy: 0.904
# Epoch: 41 / 50
# 	train loss: -0.9406456693649292, val loss: -0.9077784167289734
# 	train accuracy 0.9422333333333334, val accuracy: 0.9091
# Epoch: 42 / 50
# 	train loss: -0.9409857384681701, val loss: -0.9092625917434692
# 	train accuracy 0.9427666666666666, val accuracy: 0.9103
# Epoch: 43 / 50
# 	train loss: -0.9406329559326172, val loss: -0.9095093856811524
# 	train accuracy 0.94245, val accuracy: 0.91
# Epoch: 44 / 50
# 	train loss: -0.9417191323916118, val loss: -0.9039323376655579
# 	train accuracy 0.9433, val accuracy: 0.9046
# Epoch: 45 / 50
# 	train loss: -0.9433066579182943, val loss: -0.9063894758224488
# 	train accuracy 0.94525, val accuracy: 0.907
# Epoch: 46 / 50
# 	train loss: -0.944970295492808, val loss: -0.910838600730896
# 	train accuracy 0.9466666666666667, val accuracy: 0.9128
# Epoch: 47 / 50
# 	train loss: -0.9432692314783732, val loss: -0.9095663995742798
# 	train accuracy 0.9448166666666666, val accuracy: 0.9106
# Epoch: 48 / 50
# 	train loss: -0.9454702548662821, val loss: -0.9098446727752686
# 	train accuracy 0.94735, val accuracy: 0.9114
# Epoch: 49 / 50
# 	train loss: -0.945975314839681, val loss: -0.9092149530410767
# 	train accuracy 0.9472833333333334, val accuracy: 0.9106
# Epoch: 50 / 50
# 	train loss: -0.94648093957901, val loss: -0.91272208070755
# 	train accuracy 0.94795, val accuracy: 0.914
#
# saving history...
# saving model...
#
# done!

# %%
plot_history("01")

# %%
# !python main.py -c ../experiments/exp-b03/config-b03.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 4507.04it/s]
#
# model:
# StochasticCNN(
#   (0): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (3): ReLU()
#   (4): Conv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (5): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (6): ReLU()
#   (7): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (8): ReLU()
#   (9): Conv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (10): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (11): ReLU()
#   (12): Conv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (13): Conv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (14): ReLU()
#   (15): Conv2d(50, 10, kernel_size=(1, 1), stride=(1, 1))
#   (16): ReLU()
#   (17): Flatten(start_dim=1, end_dim=-1)
# )
#
# using device  cuda
#
# training...
#
# Epoch: 1 / 50
# 	train loss: 1.9071873972574869, val loss: 1.7758789152145387
# 	train accuracy 0.5516333333333333, val accuracy: 0.6877
# Epoch: 2 / 50
# 	train loss: 1.7430706847508748, val loss: 1.7362686138153076
# 	train accuracy 0.7198333333333333, val accuracy: 0.7254
# Epoch: 3 / 50
# 	train loss: 1.7246748631159465, val loss: 1.7321836248397826
# 	train accuracy 0.7368333333333333, val accuracy: 0.7309
# Epoch: 4 / 50
# 	train loss: 1.71486293258667, val loss: 1.7163253604888915
# 	train accuracy 0.7465833333333334, val accuracy: 0.7459
# Epoch: 5 / 50
# 	train loss: 1.7076722036997478, val loss: 1.7116097515106201
# 	train accuracy 0.7538, val accuracy: 0.7492
# Epoch: 6 / 50
# 	train loss: 1.6999757414499919, val loss: 1.7101542308807374
# 	train accuracy 0.7607666666666667, val accuracy: 0.7515
# Epoch: 7 / 50
# 	train loss: 1.6934637457529704, val loss: 1.7001766525268556
# 	train accuracy 0.7673666666666666, val accuracy: 0.7607
# Epoch: 8 / 50
# 	train loss: 1.6861917466481526, val loss: 1.6954611904144288
# 	train accuracy 0.7752333333333333, val accuracy: 0.7658
# Epoch: 9 / 50
# 	train loss: 1.6808728476842245, val loss: 1.6832860822677613
# 	train accuracy 0.78035, val accuracy: 0.7775
# Epoch: 10 / 50
# 	train loss: 1.6757627337773642, val loss: 1.6819683322906493
# 	train accuracy 0.7854, val accuracy: 0.7786
# Epoch: 11 / 50
# 	train loss: 1.6715808108011883, val loss: 1.6826157047271728
# 	train accuracy 0.78985, val accuracy: 0.7781
# Epoch: 12 / 50
# 	train loss: 1.6675731956481934, val loss: 1.6763514936447144
# 	train accuracy 0.79365, val accuracy: 0.784
# Epoch: 13 / 50
# 	train loss: 1.6642674463907878, val loss: 1.6696383647918702
# 	train accuracy 0.7969, val accuracy: 0.7904
# Epoch: 14 / 50
# 	train loss: 1.6616069910049438, val loss: 1.662594441986084
# 	train accuracy 0.79935, val accuracy: 0.7984
# Epoch: 15 / 50
# 	train loss: 1.6599721151987712, val loss: 1.665481540298462
# 	train accuracy 0.801, val accuracy: 0.7955
# Epoch: 16 / 50
# 	train loss: 1.6573497285842895, val loss: 1.6692587493896485
# 	train accuracy 0.8034333333333333, val accuracy: 0.7908
# Epoch: 17 / 50
# 	train loss: 1.6570450598398845, val loss: 1.6606910348892212
# 	train accuracy 0.8039, val accuracy: 0.8001
# Epoch: 18 / 50
# 	train loss: 1.6545889848709106, val loss: 1.6577445331573486
# 	train accuracy 0.8064, val accuracy: 0.8023
# Epoch: 19 / 50
# 	train loss: 1.6539486587524415, val loss: 1.6576085536956786
# 	train accuracy 0.8069333333333333, val accuracy: 0.8038
# Epoch: 20 / 50
# 	train loss: 1.6525866863250733, val loss: 1.655552642250061
# 	train accuracy 0.80785, val accuracy: 0.8054
# Epoch: 21 / 50
# 	train loss: 1.6507967393875123, val loss: 1.6605661254882813
# 	train accuracy 0.80995, val accuracy: 0.8009
# Epoch: 22 / 50
# 	train loss: 1.6464231775919596, val loss: 1.655520061302185
# 	train accuracy 0.8142833333333334, val accuracy: 0.8045
# Epoch: 23 / 50
# 	train loss: 1.6377239760080973, val loss: 1.6454703260421752
# 	train accuracy 0.8232833333333334, val accuracy: 0.8166
# Epoch: 24 / 50
# 	train loss: 1.6347072109222411, val loss: 1.6405986557006835
# 	train accuracy 0.8267833333333333, val accuracy: 0.8208
# Epoch: 25 / 50
# 	train loss: 1.630955099105835, val loss: 1.6377460189819335
# 	train accuracy 0.8301, val accuracy: 0.8227
# Epoch: 26 / 50
# 	train loss: 1.627813497289022, val loss: 1.6358826999664307
# 	train accuracy 0.8333833333333334, val accuracy: 0.8248
# Epoch: 27 / 50
# 	train loss: 1.6239269826253255, val loss: 1.6287799167633057
# 	train accuracy 0.837, val accuracy: 0.8325
# Epoch: 28 / 50
# 	train loss: 1.6203693433125814, val loss: 1.6287765405654908
# 	train accuracy 0.8404833333333334, val accuracy: 0.8334
# Epoch: 29 / 50
# 	train loss: 1.618301772181193, val loss: 1.6231543437957763
# 	train accuracy 0.84265, val accuracy: 0.8382
# Epoch: 30 / 50
# 	train loss: 1.6139337832768759, val loss: 1.632018685531616
# 	train accuracy 0.8476, val accuracy: 0.8278
# Epoch: 31 / 50
# 	train loss: 1.6127936883290608, val loss: 1.620197211074829
# 	train accuracy 0.8480333333333333, val accuracy: 0.8413
# Epoch: 32 / 50
# 	train loss: 1.6096794439951578, val loss: 1.620629460144043
# 	train accuracy 0.8520166666666666, val accuracy: 0.8392
# Epoch: 33 / 50
# 	train loss: 1.6076706498463949, val loss: 1.6173157836914063
# 	train accuracy 0.8540166666666666, val accuracy: 0.8439
# Epoch: 34 / 50
# 	train loss: 1.6066495655695596, val loss: 1.6181013050079345
# 	train accuracy 0.8551166666666666, val accuracy: 0.8434
# Epoch: 35 / 50
# 	train loss: 1.6044582841237387, val loss: 1.6193457225799561
# 	train accuracy 0.8569, val accuracy: 0.841
# Epoch: 36 / 50
# 	train loss: 1.603053028869629, val loss: 1.616098487854004
# 	train accuracy 0.8586666666666667, val accuracy: 0.8452
# Epoch: 37 / 50
# 	train loss: 1.6010899128595988, val loss: 1.617202886581421
# 	train accuracy 0.8601333333333333, val accuracy: 0.8431
# Epoch: 38 / 50
# 	train loss: 1.5994925189971925, val loss: 1.617539268875122
# 	train accuracy 0.8624333333333334, val accuracy: 0.8428
# Epoch: 39 / 50
# 	train loss: 1.5986621774673462, val loss: 1.6126240756988526
# 	train accuracy 0.8623333333333333, val accuracy: 0.8482
# Epoch: 40 / 50
# 	train loss: 1.5970597626368204, val loss: 1.6098353763580322
# 	train accuracy 0.8643666666666666, val accuracy: 0.8502
# Epoch: 41 / 50
# 	train loss: 1.594834397315979, val loss: 1.6065533794403075
# 	train accuracy 0.8665166666666667, val accuracy: 0.8535
# Epoch: 42 / 50
# 	train loss: 1.5945115673065187, val loss: 1.609141421699524
# 	train accuracy 0.8669166666666667, val accuracy: 0.8521
# Epoch: 43 / 50
# 	train loss: 1.5935999826431275, val loss: 1.6054419181823731
# 	train accuracy 0.8680333333333333, val accuracy: 0.8562
# Epoch: 44 / 50
# 	train loss: 1.5914041520436606, val loss: 1.606135492324829
# 	train accuracy 0.8703166666666666, val accuracy: 0.8539
# Epoch: 45 / 50
# 	train loss: 1.590978413772583, val loss: 1.6097286827087403
# 	train accuracy 0.87045, val accuracy: 0.8513
# Epoch: 46 / 50
# 	train loss: 1.5892433027903239, val loss: 1.6025535682678222
# 	train accuracy 0.87235, val accuracy: 0.8585
# Epoch: 47 / 50
# 	train loss: 1.587806835683187, val loss: 1.6037781211853028
# 	train accuracy 0.8734833333333333, val accuracy: 0.8566
# Epoch: 48 / 50
# 	train loss: 1.586538062286377, val loss: 1.5984329725265503
# 	train accuracy 0.8745666666666667, val accuracy: 0.8625
# Epoch: 49 / 50
# 	train loss: 1.586219988123576, val loss: 1.5979256198883056
# 	train accuracy 0.8746166666666667, val accuracy: 0.8617
# Epoch: 50 / 50
# 	train loss: 1.5843592011769612, val loss: 1.5942645309448242
# 	train accuracy 0.8772833333333333, val accuracy: 0.8663
#
# saving history...
# saving model...
#
# done!

# %%
plot_history("03")

# %%
# !python main.py -c ../experiments/exp-b04/config-b04.yaml
# Out:
# reading config file...
# setting up the experiment...
# building model...
# 100%|█████████████████████████████████████████| 18/18 [00:00<00:00, 2613.64it/s]
#
# model:
# StochasticCNN(
#   (0): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#   (4): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU()
#   (6): Conv2d(12, 12, kernel_size=(2, 2), stride=(2, 2))
#   (7): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (9): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1))
#   (12): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (13): ReLU()
#   (14): Conv2d(48, 48, kernel_size=(2, 2), stride=(2, 2))
#   (15): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1))
#   (17): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): ReLU()
#   (19): Conv2d(96, 96, kernel_size=(2, 2), stride=(2, 2))
#   (20): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (21): Conv2d(96, 50, kernel_size=(1, 1), stride=(1, 1))
#   (22): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (23): ReLU()
#   (24): Conv2d(50, 10, kernel_size=(1, 1), stride=(1, 1))
#   (25): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): ReLU()
#   (27): Flatten(start_dim=1, end_dim=-1)
# )
#
# using device  cuda
#
# training...
#
# Epoch: 1 / 50
# 	train loss: 1.926534896405538, val loss: 1.8240977251052857
# 	train accuracy 0.7461666666666666, val accuracy: 0.8314
# Epoch: 2 / 50
# 	train loss: 1.808801467514038, val loss: 1.7631439823150634
# 	train accuracy 0.8511666666666666, val accuracy: 0.86
# Epoch: 3 / 50
# 	train loss: 1.7569247369766234, val loss: 1.7195635549545287
# 	train accuracy 0.8728166666666667, val accuracy: 0.8742
# Epoch: 4 / 50
# 	train loss: 1.7186553468704224, val loss: 1.6924685203552245
# 	train accuracy 0.8845166666666666, val accuracy: 0.8816
# Epoch: 5 / 50
# 	train loss: 1.6906502871831257, val loss: 1.6666134447097778
# 	train accuracy 0.89285, val accuracy: 0.8887
# Epoch: 6 / 50
# 	train loss: 1.6649543294906617, val loss: 1.651480707359314
# 	train accuracy 0.9000833333333333, val accuracy: 0.8861
# Epoch: 7 / 50
# 	train loss: 1.6456057231267294, val loss: 1.6397294179916382
# 	train accuracy 0.90595, val accuracy: 0.8887
# Epoch: 8 / 50
# 	train loss: 1.6282406135559082, val loss: 1.6231565013885498
# 	train accuracy 0.9104166666666667, val accuracy: 0.8945
# Epoch: 9 / 50
# 	train loss: 1.614689337539673, val loss: 1.6121968173980712
# 	train accuracy 0.9146666666666666, val accuracy: 0.8992
# Epoch: 10 / 50
# 	train loss: 1.6015857131322224, val loss: 1.6074917583465576
# 	train accuracy 0.9196333333333333, val accuracy: 0.8974
# Epoch: 11 / 50
# 	train loss: 1.5919706146240233, val loss: 1.5981855695724487
# 	train accuracy 0.9219666666666667, val accuracy: 0.8985
# Epoch: 12 / 50
# 	train loss: 1.5828973161697388, val loss: 1.5919653324127196
# 	train accuracy 0.9245333333333333, val accuracy: 0.8999
# Epoch: 13 / 50
# 	train loss: 1.574886380259196, val loss: 1.5856635669708252
# 	train accuracy 0.9277666666666666, val accuracy: 0.9008
# Epoch: 14 / 50
# 	train loss: 1.5671907232920328, val loss: 1.5850000175476073
# 	train accuracy 0.931, val accuracy: 0.9001
# Epoch: 15 / 50
# 	train loss: 1.5606673116048178, val loss: 1.5804910978317261
# 	train accuracy 0.9337833333333333, val accuracy: 0.9017
# Epoch: 16 / 50
# 	train loss: 1.5544867965062459, val loss: 1.577280511856079
# 	train accuracy 0.9374166666666667, val accuracy: 0.9033
# Epoch: 17 / 50
# 	train loss: 1.5502295232137044, val loss: 1.5795068201065063
# 	train accuracy 0.9384333333333333, val accuracy: 0.9004
# Epoch: 18 / 50
# 	train loss: 1.5463872666041056, val loss: 1.5710406003952027
# 	train accuracy 0.9404, val accuracy: 0.9054
# Epoch: 19 / 50
# 	train loss: 1.5415615400950113, val loss: 1.5732181234359741
# 	train accuracy 0.9425333333333333, val accuracy: 0.9004
# Epoch: 20 / 50
# 	train loss: 1.5390606159845988, val loss: 1.5710455154418945
# 	train accuracy 0.9431833333333334, val accuracy: 0.9013
# Epoch: 21 / 50
# 	train loss: 1.5354009952545167, val loss: 1.5721932455062866
# 	train accuracy 0.9454166666666667, val accuracy: 0.9005
# Epoch: 22 / 50
# 	train loss: 1.5320142547607423, val loss: 1.5677907793045045
# 	train accuracy 0.94755, val accuracy: 0.904
# Epoch: 23 / 50
# 	train loss: 1.5292237564086915, val loss: 1.56723331489563
# 	train accuracy 0.9487833333333333, val accuracy: 0.9026
# Epoch: 24 / 50
# 	train loss: 1.5263887250264485, val loss: 1.56765906791687
# 	train accuracy 0.9505833333333333, val accuracy: 0.9022
# Epoch: 25 / 50
# 	train loss: 1.524746018854777, val loss: 1.5671702501296998
# 	train accuracy 0.9511, val accuracy: 0.9025
# Epoch: 26 / 50
# 	train loss: 1.5216768032073975, val loss: 1.566121939086914
# 	train accuracy 0.9532833333333334, val accuracy: 0.9026
# Epoch: 27 / 50
# 	train loss: 1.5210463918685913, val loss: 1.5700324781417847
# 	train accuracy 0.9528666666666666, val accuracy: 0.898
# Epoch: 28 / 50
# 	train loss: 1.5181567465464274, val loss: 1.5626797172546387
# 	train accuracy 0.9551, val accuracy: 0.9049
# Epoch: 29 / 50
# 	train loss: 1.5163493125279743, val loss: 1.565758134841919
# 	train accuracy 0.9564333333333334, val accuracy: 0.9024
# Epoch: 30 / 50
# 	train loss: 1.515090131187439, val loss: 1.5653608463287354
# 	train accuracy 0.9566, val accuracy: 0.9017
# Epoch: 31 / 50
# 	train loss: 1.5140380303700764, val loss: 1.5643487754821777
# 	train accuracy 0.9573833333333334, val accuracy: 0.9021
# Epoch: 32 / 50
# 	train loss: 1.512305419286092, val loss: 1.5666997913360596
# 	train accuracy 0.9586, val accuracy: 0.8995
# Epoch: 33 / 50
# 	train loss: 1.5104583330790202, val loss: 1.5644072832107543
# 	train accuracy 0.9601833333333334, val accuracy: 0.9006
# Epoch: 34 / 50
# 	train loss: 1.5099136618296305, val loss: 1.563005979156494
# 	train accuracy 0.9604333333333334, val accuracy: 0.901
# Epoch: 35 / 50
# 	train loss: 1.5085197741190592, val loss: 1.562071195793152
# 	train accuracy 0.9615, val accuracy: 0.9037
# Epoch: 36 / 50
# 	train loss: 1.5076185670216877, val loss: 1.564228176879883
# 	train accuracy 0.9615333333333334, val accuracy: 0.8999
# Epoch: 37 / 50
# 	train loss: 1.5059814297993979, val loss: 1.5624258682250975
# 	train accuracy 0.9635666666666667, val accuracy: 0.9026
# Epoch: 38 / 50
# 	train loss: 1.5058354820887248, val loss: 1.562070606613159
# 	train accuracy 0.9632, val accuracy: 0.9029
# Epoch: 39 / 50
# 	train loss: 1.5039365094502768, val loss: 1.5652274475097656
# 	train accuracy 0.9643666666666667, val accuracy: 0.8999
# Epoch: 40 / 50
# 	train loss: 1.5042333906173706, val loss: 1.562297894859314
# 	train accuracy 0.9641833333333333, val accuracy: 0.9022
# Epoch: 41 / 50
# 	train loss: 1.5025581133524577, val loss: 1.565792289352417
# 	train accuracy 0.9652166666666666, val accuracy: 0.899
# Epoch: 42 / 50
# 	train loss: 1.502026150004069, val loss: 1.5601277353286742
# 	train accuracy 0.9659333333333333, val accuracy: 0.903
# Epoch: 43 / 50
# 	train loss: 1.5009301974614462, val loss: 1.5618978172302247
# 	train accuracy 0.96665, val accuracy: 0.9023
# Epoch: 44 / 50
# 	train loss: 1.5011329353968303, val loss: 1.5603388271331786
# 	train accuracy 0.9659833333333333, val accuracy: 0.9041
# Epoch: 45 / 50
# 	train loss: 1.4994453448613485, val loss: 1.5603879444122315
# 	train accuracy 0.9673833333333334, val accuracy: 0.9041
# Epoch: 46 / 50
# 	train loss: 1.4990557360331218, val loss: 1.5608085781097412
# 	train accuracy 0.9677666666666667, val accuracy: 0.9028
# Epoch: 47 / 50
# 	train loss: 1.4986754197438559, val loss: 1.5613384536743165
# 	train accuracy 0.9680166666666666, val accuracy: 0.9018
# Epoch: 48 / 50
# 	train loss: 1.4975806944529215, val loss: 1.561676704788208
# 	train accuracy 0.9687, val accuracy: 0.9022
# Epoch: 49 / 50
# 	train loss: 1.4970217646280926, val loss: 1.5627024085998535
# 	train accuracy 0.9691833333333333, val accuracy: 0.9019
# Epoch: 50 / 50
# 	train loss: 1.4969929124832153, val loss: 1.5601469314575196
# 	train accuracy 0.9689666666666666, val accuracy: 0.9027
#
# saving history...
# saving model...
#
# done!

# %%
plot_history("04")
